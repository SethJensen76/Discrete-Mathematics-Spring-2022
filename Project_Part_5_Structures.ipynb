# %% [markdown]
# <a href="https://colab.research.google.com/github/SethJensen76/Discrete-Mathematics-Spring-2022/blob/main/Project_Part_5_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part 5 : CPSMA 3133 Discrete Mathematics
#
# ## Structures
#
# ### Seth Jensen 244476
#
# ### Instructor: Dr. Jacob

# %% [markdown]
# ## Story

# %% [markdown]
# So for my graph, I believe that I am going to do the Kansas City Chiefs front office and coaching staff. I have been a Chiefs fan for as long as I can remember, I remember watching my first Chiefs game when I was about 7 years old. I have just always been fond of them, loved their colors, but now that we are so good, I always have to explain to people that I am not a "bandwagon fan," and that gets tiring lol.

# %% [markdown]
# # Graph

# %%
import graphviz

Chiefs = graphviz.Digraph('Chiefs Front office/Coaching staff')

Chiefs.edge('Brett Veach', 'Andy Reid', label = 'Hired')
Chiefs.edge('Brett Veach', 'Andy Reid', 'Head Coach')
Chiefs.edge('Andy Reid','Spags','DC')
Chiefs.edge('Andy Reid','Eric Bienemy','OC')
Chiefs.edge('Eric Bienemy','Andy Heck','O-Line Coach')
Chiefs.edge('Andy Heck', 'Corey Matthaei', 'Assistant O-Line')
Chiefs.edge('Dave Toub', 'Andy Hill', 'Assistant Special Teams')
Chiefs.node('Hunt Family')
Chiefs.edge('Andy Reid','Dave Toub', 'Assistant HC/Special Teams')
Chiefs.edge('Andy Reid', 'Dan WIlliams', 'Assistant to the Head Coach')
Chiefs.edge('Andy Reid', 'Barry Rubin', 'Stength and Conditioning')
Chiefs.edge('Barry Rubin', 'Ryan Reynolds', 'Assistant Strength and Conditioning')
Chiefs.edge('Barry Rubin', 'Tyler Judkins', 'Assistant Strength and Conditioning')
Chiefs.edge('Barry Rubin', 'Greg Carbin', 'Assistant Strength and Conditioning')
Chiefs.edge('Hunt Family','Brett Veach','Hired')
Chiefs.edge('Hunt Family','Brett Veach','GM')
Chiefs.edge('Spags', 'Joe Cullen', 'D-Line Coach')
Chiefs.edge('Joe Cullen', 'Terry Bradden', 'Assistant D-Line')
Chiefs.edge('Eric Bienemy', 'Joe Bleymeir', 'Wide Receivers')
Chiefs.edge('Eric Bienemy', 'Greg Lewis', 'Running Backs')
Chiefs.edge('Eric Bienemy', 'Tom Melvin', 'Tight Ends')
Chiefs.edge('Eric Bienemy', 'Porter Ellot', 'Offensive Quality Control')
Chiefs.edge('Spags', 'Brendan Daly', 'Linebackers')
Chiefs.edge('Spags', 'Ken Flajole', 'Outside LBs')
Chiefs.edge('Spags', 'Sam Madison', 'Corner Backs')
Chiefs.edge('Spags', 'Dave Merrit', 'Definsive Backs')
Chiefs.edge('Spags', 'Alex Whittingham', 'Defensive Quality Control')
Chiefs

# %% [markdown]
# I know that this graph is huge, but the Chiefs have a very big and diverse coaching staff. A lot of these I knew off of the top of my head because I am a diehard fan, but some of the strength and conditioning assistants, I had no clue.
#
# For the vertex of the graph, I will use Andy Reid because almost everything branches off of him. This would also have a degree of 5, I believe.
# I also think there is not a cycle because nothing circles back into itself, everyone is under someone in the chain of command.
#
# In the end, it was a little difficult for me to kind of put this in a story, but I have always been a huge Chiefs fan, and I thought it would be really cool to make a graph/tree of the entire coaching staff.
